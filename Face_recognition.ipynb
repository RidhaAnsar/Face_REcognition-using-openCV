# %% [markdown]
# <a href="https://colab.research.google.com/github/RidhaAnsar/Face_REcognition-using-openCV/blob/main/Face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=f0d4355b43e3e8082f8e99db82a4a447e8821f912dc5d40af220e92ab9bb44f0
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
from google.colab.patches import cv2_imshow
import cv2

# %%
img=cv2.imread("/content/picc.jpeg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=195x259>

# %%
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding=face_recognition.face_encodings(rgb_img)[0]

# %%
img2=cv2.imread("/content/pic1.jpeg")
rgb_img2=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2=face_recognition.face_encodings(rgb_img2)[0]

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=602x401>

# %%
## comparing if both are same
result=face_recognition.compare_faces([img_encoding], img_encoding2)
print("Result:", result)
# Out:
# Result: [False]

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
img3=cv2.imread("/content/girl2.jpg")
rgb_img3=cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img_encoding3=face_recognition.face_encodings(rgb_img3)[0]

# %%
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=768x579>
